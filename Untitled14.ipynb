# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_excel("/content/zomato.xlsx")

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# findind missing values
# 1.missing values
# 2.explore about te numerical variables
# 3.explore about categorial values
# 4.finding relTIONSHIP BETWEEN FEATURES

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
[features for features in df.columns if df[features].isnull().sum()>0]
# Out:
# ['Cuisines']

# %%
df.shape
# Out:
# (9551, 21)

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap="viridis")
# Out:
# <Axes: >

# %%
df_c=pd.read_excel("Country-Code.xlsx")

# %%
df_c.head()
# Out:
#    Country Code    Country
# 0          94.0  Indonesia
# 1          94.0  Indonesia
# 2           NaN        NaN
# 3         191.0  Sri Lanka
# 4         214.0        UAE

# %%
final_df=pd.merge(df,df_c,on="Country Code",how="left")

# %%
final_df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
# 1  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
# 1  French, Japanese, Desserts  ...                Yes                  No
#
# ...

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
country_names=final_df.Country.value_counts().index
country_names
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'UAE',
#        'South Africa', 'Indonesia', 'Turkey', 'Phillipines', 'New Zealand',
#        'Australia', 'Singapore', 'Qatar', 'Sri Lanka', 'Canada'],
#       dtype='object', name='Country')

# %%
country_val=final_df.Country.value_counts().values
country_val
# Out:
# array([112476,   5208,   1360,   1020,    900,    840,    462,    408,
#           330,    320,    288,    280,    280,    160,     24])

# %% [markdown]
# pie chart-top 3 countries that usews zomato

# %%
plt.pie(country_val[:3],labels=country_names[:3],autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7a2d8b09ad40>,
# ...
#  [Text(-1.083517394832553, 0.18971045067491038, 'India'),
#   Text(1.0760122537287142, -0.22846800613139118, 'United States'),
#   Text(1.0992916044697443, -0.039471107690759975, 'United Kingdom')],
#  [Text(-0.5910094880904834, 0.1034784276408602, '94.48%'),
#   Text(0.5869157747611168, -0.12461891243530426, '4.37%'),
#   Text(0.5996136024380422, -0.02152969510405089, '1.14%')])

# %% [markdown]
# numperical variable

# %%
rating=final_df.groupby(["Aggregate rating","Rating color","Rating text"]).size().reset_index().rename(columns={0:"rating count"})

# %%
rating
# Out:
#     Aggregate rating Rating color Rating text  rating count
# 0                0.0        White   Not rated         27945
# 1                1.8          Red        Poor            13
# 2                1.9          Red        Poor            26
# 3                2.0          Red        Poor            91
# 4                2.1          Red        Poor           195
# 5                2.2          Red        Poor           350
# 6                2.3          Red        Poor           606
# 7                2.4          Red        Poor          1126
# 8                2.5       Orange     Average          1425
# 9                2.6       Orange     Average          2482
# 10               2.7       Orange     Average          3250
# 11               2.8       Orange     Average          4099
# 12               2.9       Orange     Average          4952
# 13               3.0       Orange     Average          6082
# 14               3.1       Orange     Average          6763
# ...

# %% [markdown]
# observations
# when rating is from 4.5 to 4.9 then excelent
# when rating is from 4.0 to 3.4 then very good
# wheen rating is between 3.5 to 3.9 then it is good
# when rating is between 3.0 to 3.4 then it is average
# when rating is between 2.5 to 2.9 then it is average
# when rating is between 2.0 to 2.4 then it is poor

# %%
rating.head()
# Out:
#    Aggregate rating Rating color Rating text  rating count
# 0               0.0        White   Not rated         27945
# 1               1.8          Red        Poor            13
# 2               1.9          Red        Poor            26
# 3               2.0          Red        Poor            91
# 4               2.1          Red        Poor           195

# %%
matplotlib.rcParams['figure.figsize']=(12,6)
sns.barplot(x="Aggregate rating",y="rating count",data=rating)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='rating count'>

# %%
matplotlib.rcParams['figure.figsize']=(12,6)
sns.barplot(x="Aggregate rating",y="rating count",hue="Rating color",data=rating,palette=['white','red','orange','yellow','green','green'])
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='rating count'>

# %% [markdown]
# observation
# 1 not rated count is very high
# 2 maximum number of rating are between 2.5 to 3.4

# %%
sns.countplot(x="Rating color",data=rating,palette=['white','red','orange','yellow','green','green'])
# Out:
# <ipython-input-104-18521c4a34fb>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Rating color",data=rating,palette=['white','red','orange','yellow','green','green'])
# <Axes: xlabel='Rating color', ylabel='count'>

# %% [markdown]
# find the countries name that has given zero rating

# %%
final_df[final_df["Rating color"]=='White'].groupby('Country').size().reset_index().head()
# Out:
#           Country      0
# 0          Brazil     85
# 1           India  27807
# 2  United Kingdom     17
# 3   United States     36

# %% [markdown]
# oservation
# maximum number of 0 rating are from indian customers

# %% [markdown]
# # next ques is find out which currency is used by which contry

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df[['Country','Currency']].groupby(['Country',"Currency"]).size().reset_index().head()
# Out:
#      Country                Currency       0
# 0  Australia               Dollar($)     288
# 1     Brazil      Brazilian Real(R$)    1020
# 2     Canada               Dollar($)      24
# 3      India      Indian Rupees(Rs.)  112476
# 4  Indonesia  Indonesian Rupiah(IDR)     462

# %% [markdown]
# which country do have online delivery options

# %%
final_df[final_df['Has Online delivery']=="Yes"].Country.value_counts()
# Out:
# Country
# India    31499
# UAE        420
# Name: count, dtype: int64

# %%
final_df[['Has Online delivery','Country']].groupby(['Has Online delivery',"Country"]).size().reset_index()
# Out:
#    Has Online delivery         Country      0
# 0                   No       Australia    288
# 1                   No          Brazil   1020
# 2                   No          Canada     24
# 3                   No           India  80977
# 4                   No       Indonesia    462
# 5                   No     New Zealand    320
# 6                   No     Phillipines    330
# 7                   No           Qatar    280
# 8                   No       Singapore    280
# 9                   No    South Africa    840
# 10                  No       Sri Lanka    160
# 11                  No          Turkey    408
# 12                  No             UAE    480
# 13                  No  United Kingdom   1360
# 14                  No   United States   5208
# 15                 Yes           India  31499
# 16                 Yes             UAE    420

# %% [markdown]
# observatios=
# online dlivery are available in india and uae+

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %% [markdown]
# create a pie chart for top 5 cities distribution
#
# > Add blockquote

# %%
final_df.City.value_counts().index
# Out:
# Index(['New Delhi', 'Gurgaon', 'Noida', 'Faridabad', 'Jakarta',
#        'Rio de Janeiro', 'Birmingham', 'London', 'Manchester', 'Sí£o Paulo',
#        ...
#        'Monroe', 'Miller', 'Middleton Beach', 'Mc Millan', 'Mayfield', 'Lorn',
#        'Yorkton', 'Chatham-Kent', 'Consort', 'Vineland Station'],
#       dtype='object', name='City', length=141)

# %%
city_values=final_df.City.value_counts().values
city_labels=final_df.City.value_counts().index

# %%
plt.pie(city_values[:5],labels=city_labels[:5],autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7a2d8673f550>,
# ...
#  [Text(-0.614019427238487, 0.9126774583464415, 'New Delhi'),
#   Text(0.060998995595186296, -1.0983073898214373, 'Gurgaon'),
#   Text(0.8779292218872674, -0.6627520511898982, 'Noida'),
#   Text(1.0920101294567304, -0.13234000590862582, 'Faridabad'),
#   Text(1.0999370178325603, -0.011771015317901829, 'Jakarta')],
#  [Text(-0.33491968758462926, 0.49782406818896807, '68.85%'),
#   Text(0.03327217941555616, -0.5990767580844203, '14.06%'),
#   Text(0.4788704846657822, -0.3615011188308535, '13.59%'),
#   Text(0.5956418887945801, -0.07218545776834136, '3.16%'),
#   Text(0.5999656460904873, -0.006420553809764634, '0.34%')])

# %% [markdown]
# top 10 cusines

# %%
final_df
# Out:
#         Restaurant ID           Restaurant Name  Country Code         City  \
# 0             6317637          Le Petit Souffle           162  Makati City
# 1             6317637          Le Petit Souffle           162  Makati City
# 2             6317637          Le Petit Souffle           162  Makati City
# 3             6317637          Le Petit Souffle           162  Makati City
# 4             6317637          Le Petit Souffle           162  Makati City
# ...               ...                       ...           ...          ...
# 124351        5927402  Walter's Coffee Roastery           208    ÛÁstanbul
# 124352        5927402  Walter's Coffee Roastery           208    ÛÁstanbul
# 124353        5927402  Walter's Coffee Roastery           208    ÛÁstanbul
# 124354        5927402  Walter's Coffee Roastery           208    ÛÁstanbul
# 124355        5927402  Walter's Coffee Roastery           208    ÛÁstanbul
#
#                                                   Address  \
# ...

# %% [markdown]
# A retail company "ABC Private Limited wants to understand the customer purchase behaviour (specially, purchase amount) against var6ious products of different categories.  They have shared purchase summary of various customers deographics(age, gender , marital_status, city_type.stay_in_city), product details(product_id and product_category)and total purchase_amouunt for the last month.
#
# Now, they want to build a model to predict the purchase amount of customer against  different products which will help them to create personalized offer for customers against different products.

# %%
df_train=pd.read_csv('train.csv')
df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df_test=pd.read_csv("test.csv")
df_test
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 783667 entries, 0 to 550067
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  783667 non-null  object
#  1   Gender                      0 non-null       float64
#  2   Age                         783667 non-null  object
#  3   Occupation                  783667 non-null  int64
#  4   City_Category               783667 non-null  object
#  5   Stay_In_Current_City_Years  783667 non-null  object
#  6   Marital_Status              783667 non-null  int64
#  7   Product_Category_1          783667 non-null  int64
#  8   Product_Category_2          537685 non-null  float64
#  9   Product_Category_3          237858 non-null  float64
#  10  Purchase                    550068 non-null  float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 71.7+ MB

# %%
df=pd.concat([df_test,df_train],axis=0)
print(df)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...
