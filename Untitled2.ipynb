# %% [markdown]
# <a href="https://colab.research.google.com/github/Pjname/Assignment-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.shape
# Out:
# (17000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
df=df.iloc[:-1,:]

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16994    -124.25     40.28                32.0       1430.0           419.0
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
#
# ...

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['latitude'],df['longitude'],c=df['total_rooms'])

# %%
x=df.iloc[:,0:3]
y=df.iloc[:,0:3]

# %%
from sklearn.model_selection import train_test_split
xtr,xts,ytr,yts=train_test_split(x,y,test_size=0.1)

# %%
xtr
# Out:
#        longitude  latitude  housing_median_age
# 5457     -118.16     34.02                34.0
# 13026    -121.86     37.35                35.0
# 3218     -117.85     33.77                23.0
# 15995    -122.44     37.78                52.0
# 3115     -117.82     33.73                24.0
# ...          ...       ...                 ...
# 11769    -121.32     38.63                20.0
# 11280    -121.13     38.66                 2.0
# 15583    -122.34     37.55                44.0
# 8582     -118.52     34.32                18.0
# 15783    -122.41     37.77                52.0
#
# [15299 rows x 3 columns]

# %%
ytr
# Out:
#        longitude  latitude  housing_median_age
# 5457     -118.16     34.02                34.0
# 13026    -121.86     37.35                35.0
# 3218     -117.85     33.77                23.0
# 15995    -122.44     37.78                52.0
# 3115     -117.82     33.73                24.0
# ...          ...       ...                 ...
# 11769    -121.32     38.63                20.0
# 11280    -121.13     38.66                 2.0
# 15583    -122.34     37.55                44.0
# 8582     -118.52     34.32                18.0
# 15783    -122.41     37.77                52.0
#
# [15299 rows x 3 columns]

# %%
xts
# Out:
#        longitude  latitude  housing_median_age
# 8052     -118.42     34.06                52.0
# 10946    -120.87     37.05                29.0
# 4834     -118.09     33.85                19.0
# 12505    -121.62     36.14                25.0
# 15333    -122.29     38.31                25.0
# ...          ...       ...                 ...
# 7891     -118.40     34.04                40.0
# 1933     -117.29     33.06                20.0
# 14535    -122.15     37.70                36.0
# 190      -116.35     32.74                16.0
# 6889     -118.30     33.79                21.0
#
# [1700 rows x 3 columns]

# %%
yts
# Out:
#        longitude  latitude  housing_median_age
# 8052     -118.42     34.06                52.0
# 10946    -120.87     37.05                29.0
# 4834     -118.09     33.85                19.0
# 12505    -121.62     36.14                25.0
# 15333    -122.29     38.31                25.0
# ...          ...       ...                 ...
# 7891     -118.40     34.04                40.0
# 1933     -117.29     33.06                20.0
# 14535    -122.15     37.70                36.0
# 190      -116.35     32.74                16.0
# 6889     -118.30     33.79                21.0
#
# [1700 rows x 3 columns]

# %%
from sklearn.preprocessing import  StandardScaler

# %%
s=StandardScaler()

# %%
list=s.fit_transform(xtr)

# %%
list
# Out:
# array([[ 0.69896931, -0.75179674,  0.42941327],
#        [-1.14362595,  0.80383877,  0.50880508],
#        [ 0.85334892, -0.86858619, -0.44389673],
#        ...,
#        [-1.38266534,  0.89727033,  1.22333145],
#        [ 0.51968977, -0.61164939, -0.84085582],
#        [-1.41752525,  1.00004505,  1.85846599]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
clf.fit(xtr,ytr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-fee56f325882> in <cell line: 1>()
# ----> 1 clf.fit(xtr,ytr)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1194             _dtype = [np.float64, np.float32]
#    1195
# -> 1196         X, y = self._validate_data(
#    1197             X,
#    1198             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# ...
